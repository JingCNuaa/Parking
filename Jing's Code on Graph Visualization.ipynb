# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()
G.add_node('CB', pos = ( -71.089669,42.339341 ))
G.add_node('MA', pos = ( -71.084451,42.341267 ))
G.add_node('SL', pos = ( -71.087959,42.338381 ))
G.add_node('MC', pos = ( -71.09036,42.34032 ))
G.add_node('ISEC', pos = ( -71.086925,42.337681 ))
G.add_node('RPG', pos = ( -71.088421,42.336297 ))
G.add_node('RY', pos = ( -71.090643,42.336601 ))
G.add_node('140', pos = ( -71.091759,42.340789 ))
G.add_node('FR', pos = ( -71.089586,42.338587 ))
G.add_node('WVA', pos = ( -71.093008,42.33747 ))
G.add_node('DCA', pos = ( -71.084599,42.337827 ))
G.add_node('EC', pos = ( -71.088899,42.33768 ))
G.add_node('MU', pos = ( -71.087148,42.339855 ))
G.add_node('WVG', pos = ( -71.091866,42.338257 ))
G.add_node('SP', pos = ( -71.089676,42.34066 ))
G.add_node('RP', pos = ( -71.088216,42.335593 ))
G.add_node('DG', pos = ( -71.087807,42.340299 ))
G.add_node('WVE', pos = ( -71.091751,42.336552 ))
G.add_node('BK', pos = ( -71.091534,42.336948 ))
G.add_node('WPG', pos = ( -71.091634,42.336748 ))
G.add_node('CP', pos = ( -71.085177,42.337609 ))
G.add_node('HT', pos = ( -71.086163,42.339781 ))
G.add_node('SH', pos = ( -71.090241,42.337603 ))
G.add_node('WVC', pos = ( -71.092541,42.336954 ))
G.add_node('KN', pos = ( -71.090847,42.339196 ))
G.add_node('DCB', pos = ( -71.084249,42.33825 ))
G.add_node('CH', pos = ( -71.088901,42.33878 ))
G.add_node('177', pos = ( -71.082787,42.344946 ))
G.add_node('RB', pos = ( -71.086725,42.339267 ))
G.add_node('CN', pos = ( -71.086532,42.340099 ))
G.add_node('PP', pos = ( -71.090467,42.337977 ))
G.add_node('CG', pos = ( -71.091086,42.3389 ))
G.add_node('ST', pos = ( -71.09136,42.339015 ))
G.add_node('MH', pos = ( -71.091172,42.342117 ))
G.add_node('KH', pos = ( -71.091262,42.341882 ))
G.add_node('LT', pos = ( -71.089747,42.338175 ))
G.add_node('AC', pos = ( -71.090339,42.343181 ))
G.add_node('INVO', pos = ( -71.088991,42.335153 ))
G.add_node('INV', pos = ( -71.08947,42.335103 ))
G.add_node('SB', pos = ( -71.086025,42.338207 ))
G.add_node('CPG', pos = ( -71.086397,42.33818 ))
G.add_node('780', pos = ( -71.086795,42.336767 ))
G.add_node('CV', pos = ( -71.08595,42.336946 ))
G.add_node('LV', pos = ( -71.085496,42.337175 ))
G.add_node('WVF', pos = ( -71.091639,42.337451 ))
G.add_node('AF', pos = ( -71.091271,42.337595 ))
G.add_node('ME', pos = ( -71.090864,42.337642 ))
G.add_node('HO', pos = ( -71.090806,42.338014 ))
G.add_node('NI', pos = ( -71.090092,42.338105 ))
G.add_node('LA', pos = ( -71.090585,42.338288 ))
G.add_node('WVH', pos = ( -71.092301,42.338556 ))
G.add_node('768', pos = ( -71.086192,42.33716 ))
G.add_node('DA', pos = ( -71.089336,42.33809 ))
G.add_node('SN', pos = ( -71.088857,42.33829 ))
G.add_node('RU', pos = ( -71.093447,42.33829 ))
G.add_node('450', pos = ( -71.092827,42.338571 ))
G.add_node('BU', pos = ( -71.093106,42.338362 ))
G.add_node('KA', pos = ( -71.090867,42.338647 ))
G.add_node('DK', pos = ( -71.090478,42.338679 ))
G.add_node('RI', pos = ( -71.088826,42.339895 ))
G.add_node('HA', pos = ( -71.088477,42.339336 ))
G.add_node('EL', pos = ( -71.087935,42.339605 ))
G.add_node('CSC', pos = ( -71.087568,42.339099 ))
G.add_node('EV', pos = ( -71.086878,42.340488 ))
G.add_node('HS', pos = ( -71.08747,42.340437 ))
G.add_node('271', pos = ( -71.086432,42.342029 ))
G.add_node('337', pos = ( -71.088819,42.340727 ))
G.add_node('319', pos = ( -71.087945,42.341049 ))
G.add_node('106-122', pos = ( -71.089091,42.340995 ))
G.add_node('LH', pos = ( -71.088155,42.341818 ))
G.add_node('FC', pos = ( -71.08786,42.342056 ))
G.add_node('236', pos = ( -71.084033,42.343029 ))
G.add_node('216', pos = ( -71.085272,42.345026 ))
G.add_node('BV', pos = ( -71.083678,42.345381 ))
G.add_node('KDY', pos = ( -71.090444,42.342983 ))
G.add_node('SM', pos = ( -71.090575,42.342516 ))
G.add_node('CA', pos = ( -71.091518,42.34148 ))
G.add_node('CU', pos = ( -71.091414,42.341675 ))
G.add_node('142-148', pos = ( -71.090227,42.342071 ))
G.add_node('LF', pos = ( -71.090943,42.341733 ))
G.add_node('SW', pos = ( -71.090643,42.340953 ))
G.add_node('SE', pos = ( -71.090202,42.34136 ))
G.add_node('WH', pos = ( -71.091142,42.339941 ))
G.add_node('407', pos = ( -71.091494,42.339584 ))
G.add_node('WVB', pos = ( -71.092136,42.337606 ))
G.add_node('AS', pos = ( -71.089104,42.337126 ))
G.add_node('WI', pos = ( -71.091433,42.338027 ))
G.add_node('GPG', pos = ( -71.085729,42.340394 ))
G.add_node('BPG', pos = ( -71.085169,42.343277 )) # 300


# huntington ave side 2
G.add_edge("407", "WH", weight= 0.1) 
G.add_edge("WH", "MC", weight= 0.2)
G.add_edge("MC", "SP", weight= 0.2)
G.add_edge("337", "SP", weight= 0.2)
G.add_edge("337", "319", weight= 0.3)
G.add_edge("319", "271", weight= 0.4)
G.add_edge("BPG", "271", weight= 0.6)
G.add_edge("BPG", "177", weight= 0.6)

# huntington ave side 1
G.add_edge("RU", "BU", weight= 0.05)
G.add_edge("450", "BU", weight= 0.05)
G.add_edge("450", "WVH", weight= 0.1)
G.add_edge("ST", "WVH", weight= 0.3)
G.add_edge("ST", "CG", weight= 0.1)
G.add_edge("KN", "CG", weight= 0.1)
G.add_edge("KN", "CB", weight= 0.3)
G.add_edge("RI", "CB", weight= 0.3)
G.add_edge("RI", "DG", weight= 0.3)
G.add_edge("HS", "DG", weight= 0.1)
G.add_edge("HS", "EV", weight= 0.2)
G.add_edge("EV", "236", weight= 20)

# connection huntington ave

G.add_edge("RI", "SP", weight= 0.4)
G.add_edge("CB", "MC", weight= 0.4)
G.add_edge("HS", "319", weight= 0.4)


# columbus ave side 1
G.add_edge("RPG", "ISEC", weight= 0.6)
G.add_edge("ISEC", "CPG", weight= 0.2)
G.add_edge("CPG", "SB", weight= 0.1)

# connection
G.add_edge("RPG", "RP", weight= 0.1)
G.add_edge("ISEC", "768", weight= 0.1)
G.add_edge("CPG", "LV", weight= 0.1)
G.add_edge("SB", "CP", weight= 0.1)

# columbus ave side 2
G.add_edge("INV", "INVO", weight= 0.1)
G.add_edge("INVO", "RP", weight= 0.2)
G.add_edge("RP", "780", weight= 0.5)
G.add_edge("768", "780", weight= 0.2)
G.add_edge("768", "LV", weight= 0.1 )
G.add_edge("LV", "CP", weight= 0.1)
G.add_edge("CP", "DCA", weight= 0.1)
G.add_edge("DCA", "DCB", weight= 0.1)

# other 
G.add_edge("768", "CV", weight= 0.1 )

# Forsyth Street side 1
G.add_edge("EC", "AS", weight= 0.2 )
G.add_edge("EC", "DA", weight= 0.2 )
G.add_edge("DA", "LT", weight= 0.1 )
G.add_edge("LT", "FR", weight= 0.1 )
G.add_edge("FR", "CB", weight= 0.3 )

# Forsyth Street side 2
G.add_edge("SH", "NI", weight= 0.2 )
G.add_edge("NI", "DK", weight= 0.2 )
G.add_edge("DK", "KN", weight= 0.2 )

# connection
G.add_edge("SH", "EC", weight= 0.5 )
G.add_edge("NI", "LT", weight= 0.1 )
G.add_edge("DK", "CB", weight= 0.4 )
G.add_edge("DK", "FR", weight= 0.2 )

# ruggle st
G.add_edge("RY", "WVE", weight= 0.3 )
G.add_edge("WVE", "WVC", weight= 0.3 )
G.add_edge("WVC", "WVA", weight= 0.3 )

# other 
G.add_edge("WVC", "WVB", weight= 0.3 )
G.add_edge("WVB", "WVA", weight= 0.3 )

# hemenway st side 1 
G.add_edge("407", "WH", weight= 0.2 )
G.add_edge("WH", "SW", weight= 0.4 )
G.add_edge("SW", "SE", weight= 0.2 )
G.add_edge("SE", "142-148", weight= 0.4 )

# hemenway st side 2 
G.add_edge("140", "LF", weight= 0.4 )
G.add_edge("LF", "SM", weight= 0.3 )
G.add_edge("SM", "KDY", weight= 0.2 )
G.add_edge("KDY", "AC", weight= 0.1 )
G.add_edge("CA", "CU", weight= 0.1 )
G.add_edge("CU", "KH", weight= 0.1 )
G.add_edge("KH", "MH", weight= 0.1 )

# other 

G.add_edge("CA", "SW", weight= 0.4 )
G.add_edge("140", "SW", weight= 0.4 )

# st stephen st

G.add_edge("106-122", "LH", weight= 0.4 )
G.add_edge("LH", "FC", weight= 0.1 )

# connection st stephen st & hunington
G.add_edge("106-122", "337", weight= 0.1 )


# ally one 

G.add_edge("FR", "CH", weight= 0.2 )
G.add_edge("CH", "HA", weight= 0.2 )
G.add_edge("HA", "EL", weight= 0.2 )
G.add_edge("EL", "MU", weight= 0.2 )
G.add_edge("MU", "CN", weight= 0.2 )
G.add_edge("CN", "GPG", weight= 0.2 )
G.add_edge("MA", "GPG", weight= 0.5 )

# ally two
G.add_edge("SN", "DA", weight= 0.1 )
G.add_edge("SN", "SL", weight= 0.3 )
G.add_edge("SL", "CSC", weight= 0.3 )
G.add_edge("CSC", "RB", weight= 0.3 )
G.add_edge("RB", "HT", weight= 0.3 )

# ally one and two connection

G.add_edge("SN", "CH", weight= 0.2 )
G.add_edge("HA", "SL", weight= 0.4 )
G.add_edge("CSC", "EL", weight= 0.1 )
G.add_edge("MU", "RB", weight= 0.2 )
G.add_edge("HT", "CN", weight= 0.1 )


# ally one and huntington ave connection

G.add_edge("MU", "HS", weight= 0.2 )
G.add_edge("HA", "RI", weight= 0.2 )
G.add_edge("EV", "CN", weight= 0.2 )
G.add_edge("DG", "EL", weight= 0.2 )

# ally two and columbus ave connection

G.add_edge("ISEC", "SL", weight= 0.4 )
G.add_edge("CPG", "RB", weight= 0.4 )
G.add_edge("AS", "RPG", weight= 0.4 )
G.add_edge("AS", "RY", weight= 0.6 )

# leon st side 1

G.add_edge("ST", "CG", weight= 0.1 )
G.add_edge("CG", "KA", weight= 0.1 )
G.add_edge("KA", "LA", weight= 0.1 )
G.add_edge("LA", "HO", weight= 0.1 )
G.add_edge("HO", "ME", weight= 0.4 )

# leon st side 2

G.add_edge("WI", "CG", weight= 0.4 )
G.add_edge("WI", "AF", weight= 0.2 )
G.add_edge("AF", "BK", weight= 0.3 )
G.add_edge("WPG", "BK", weight= 0.05 )


# other 
G.add_edge("WVE", "WPG", weight= 0.05 )
G.add_edge("AF", "WVF", weight= 0.1 )
G.add_edge("WVF", "WVB", weight= 0.1 )
G.add_edge("WI", "WVG", weight= 0.15 )
G.add_edge("WVF", "WVG", weight= 0.15 )
G.add_edge("WVH", "WVG", weight= 0.15 )
G.add_edge("WVB", "WVG", weight= 0.2 )
G.add_edge("BPG", "216", weight= 0.6 )
G.add_edge("216", "BV", weight= 0.4 )
G.add_edge("177", "BV", weight= 0.3 )


# leon and forsyth

G.add_edge("ME", "ST", weight= 0.2 )
G.add_edge("LA", "NI", weight= 0.1 )
G.add_edge("KA", "DK", weight= 0.1 )



road = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] >= 0]

# nodes

nx.get_node_attributes(G, 'pos')
position = nx.get_node_attributes(G, 'pos')

plt.figure(3,figsize=(14,14)) 
nx.draw(G, nx.get_node_attributes(G, 'pos'), with_labels=True, node_size=200,node_color='#a0d9c5')

distance = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, position, distance, font_size=10)

P = nx.Graph()

P.add_node('CPG', pos = ( -71.086397,42.33818 ))
P.add_node('GPG', pos = ( -71.085729,42.340394 ))
P.add_node('RPG', pos = ( -71.088421,42.336297 ))
P.add_node('BPG', pos = ( -71.085169,42.343277 ))
P.add_node('WPG', pos = ( -71.091634,42.336748 ))

nx.draw(P, nx.get_node_attributes(G, 'pos'), node_size=1000,node_color='#e6a39c')


O = nx.Graph()

O.add_node('RY', pos = ( -27.2451494688623,78.1279024216445 ))
O.add_node('FC', pos = ( -71.08786,42.342056 ))
O.add_node('MA', pos = ( -71.084451,42.341267 ))
O.add_node('142-148', pos = ( -71.090227,42.342071 ))
O.add_node('140', pos = ( -71.091759,42.340789 ))
nx.draw(O, nx.get_node_attributes(G, 'pos'), node_size=1000,node_color='#daa7eb')


plt.show()

# %%
pip install contextily
